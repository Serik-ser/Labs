# %% [markdown]
# <a href="https://colab.research.google.com/github/Serik-ser/Labs/blob/main/Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Республіка Джибуті
#
# ## 1. Загальна інформація
#
# **Джибуті** — це країна у Східній Африці, розташована в районі Африканського Рогу.
# Вона межує з Еритреєю на півночі, Ефіопією на заході та півдні, і Сомалі на південному сході.
#
# * **Офіційна назва:** Республіка Джибуті
# * *Девіз:* "Єдність, Рівність, Мир"
# * **Офіційні мови:** <span style='color:blue'>Французька</span> та <span style='color:green'>Арабська</span>
#
# ---
#
# <div style='border: 2px solid #D80C13; padding: 10px; border-radius: 5px;'>
#   <b>Геополітичне значення:</b> Джибуті має стратегічне розташування на протоці Баб-ель-Мандеб, яка з'єднує Червоне море та Аденську затоку.
# </div>
#
# ## 2. Ключові факти
#
# | Характеристика | Дані |
# | :--- | :--- |
# | **Столиця** | м. Джибуті |
# | **Площа** | ~23 200 км² |
# | **Населення** | ~1.1 млн (оцінка 2024-2025) |
# | **Валюта** | Джибутійський франк (DJF) |
#
# ---
#
# ## 3. Пам'ятки та природа
#
# Джибуті відома своїми унікальними геологічними ландшафтами.
#
# 1.  **Природні дива:**
#     * Озеро Ассаль (найнижча точка Африки).
#     * Озеро Аббе (вапнякові "димарі").
#     * Національний парк Дей Форест.
# 2.  **Морська фауна:**
#     * Дайвінг (коралові рифи).
#     * Сезонне спостереження за китовими акулами.
#
# ### Ландшафт Джибуті
#
# ![Ландшафт біля озера Ассаль](https://dynamic-media-cdn.tripadvisor.com/media/photo-o/07/8f/5a/87/lake-assal.jpg?w=1400&h=800&s=1)
#
# ---
#
# ## 4. Додаткові ресурси
#
# Для отримання детальнішої інформації, ви можете відвідати сторінку у Вікіпедії.
# * <a href="https://uk.wikipedia.org/wiki/Джибуті" target="_blank">Стаття у Вікіпедії про Джибуті</a>
#
# ---
#
# ## 5. Прапор Джибуті (намальований за допомогою <svg>)

# %%
# %%html
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 36 20" width="360" height="200">
#   <!-- верхняя голубая полоса -->
#   <rect x="0" y="0" width="36" height="10" fill="#6ab2e7" />
#   <!-- нижняя зеленая полоса -->
#   <rect x="0" y="10" width="36" height="10" fill="#12ad2b" />
#
#   <!-- белый треугольник слева -->
#   <polygon points="0,0 16,10 0,20" fill="#ffffff" />
#
#   <!-- красная звезда -->
#   <polygon
#     points="8.00,7.00 8.71,9.03 10.85,9.07 9.14,10.37 9.76,12.43 8.00,11.20 6.24,12.43 6.86,10.37 5.15,9.07 7.29,9.03"
#     fill="#ce1126"
#   />
# </svg>
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 36 20" width="360" height="200">
#   <!-- верхняя голубая полоса -->
#   <rect x="0" y="0" width="36" height="10" fill="#6ab2e7" />
#   <!-- нижняя зеленая полоса -->
#   <rect x="0" y="10" width="36" height="10" fill="#12ad2b" />
#
#   <!-- белый треугольник слева -->
#   <polygon points="0,0 16,10 0,20" fill="#ffffff" />
#
#   <!-- красная звезда -->
#   <polygon
#     points="8.00,7.00 8.71,9.03 10.85,9.07 9.14,10.37 9.76,12.43 8.00,11.20 6.24,12.43 6.86,10.37 5.15,9.07 7.29,9.03"
#     fill="#ce1126"
#   />
# </svg>

# %%
def bubble_sort_with_swaps(numbers):
  """
  Сортує список методом бульбашки та повертає кількість переставлень.
  """
  n = len(numbers)
  swaps = 0  # Лічильник переставлень

  # Зовнішній цикл для проходів
  for i in range(n - 1):
    # Внутрішній цикл для порівнянь
    for j in range(0, n - i - 1):
      # Порівнюємо два сусідні елементи
      if numbers[j] > numbers[j + 1]:
        # Якщо вони не по порядку, міняємо їх місцями
        numbers[j], numbers[j + 1] = numbers[j + 1], numbers[j]
        swaps += 1  # Збільшуємо лічильник переставлень

  return swaps

def task4():
  """
  Головна функція для Завдання 4.
  Отримує ввід, обробляє помилки та викликає сортування.
  """
  print("Введіть список чисел через пробіл:")
  user_input = input()

  try:
    # 1. Розбиваємо рядок на список рядків по пробілу
    str_list = user_input.split()

    # 2. Конвертуємо кожен елемент у ціле число (int)
    #    Це місце, де виникне помилка, якщо введено не число
    numbers = [int(num) for num in str_list]

    # 3. Якщо конвертація успішна, викликаємо сортування
    swap_count = bubble_sort_with_swaps(numbers)

    # 4. Виводимо результат у форматі, як у завданні
    print(f"Було виконано {swap_count} переставлень")

  except ValueError:
    # 5. Обробка помилки, якщо `int(num)` не спрацювало
    #    Використовуємо точне повідомлення про помилку з PDF
    print("Помилка. У списку присутнє нечислове значення")

# %%
task4()
# Out:
# Введіть список чисел через пробіл:
# 5 6 23 8 12 5
# Було виконано 6 переставлень

# %%
task4()
# Out:
# Введіть список чисел через пробіл:
# 7 3 1 7 4 2 8 2
# Було виконано 14 переставлень

# %%
task4()
# Out:
# Введіть список чисел через пробіл:
# 3 4 23 str 3 4
# Помилка. У списку присутнє нечислове значення
